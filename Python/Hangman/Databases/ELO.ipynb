# %%
rPlayer = 0
rWord = 0

# %% [markdown]
# rPlayer = Player rating
# rWord = Word ave_guesses
# pPlayer = Player win probability
# pWord = Player loss probability

# %%
pPlayer = rPlayer / (rPlayer+rWord)
pWord = rWord / (rPlayer+rWord)
